# %%
import pandas as pd

la_apts = pd.read_csv ('Resources/la_apts_coords.csv')
coords_df = la_apts[['Latitude', 'Longitude']]
coords_df
# Out:
#        Latitude   Longitude
# 0     34.083828 -118.360519
# 1     34.045212 -118.256907
# 2     34.053617 -118.261687
# 3     34.134967 -118.210946
# 4     34.015212 -118.347009
# ...         ...         ...
# 3115  34.053227 -118.267140
# 3116  34.098559 -118.347910
# 3117  34.043812 -118.261707
# 3118  34.154840 -118.248008
# 3119  34.223501 -118.453616
#
# [3120 rows x 2 columns]

# %%
import googlemaps
gmaps = googlemaps.Client(key='AIzaSyCnYHZHMZCq0TT1eaV_tXlhpbPZ6tl-xkU')

iterations = 0

zipcodes = []

for row in coords_df[['Latitude', 'Longitude']].itertuples():
    
    reverse_geocode_result = gmaps.reverse_geocode((row[1], row[2]))
        
    for component in reverse_geocode_result[0]['address_components']:
        zipcode = None
                
        if "postal_code" in component["types"]:
            zipcode = component['long_name']
            break
            
    zipcodes.append(zipcode)

    iterations += 1
    print(str(iterations) + " zips converted successfully!")

print("\n")

print("zip conversion complete!")
# Out:
# 1 zips converted successfully!
# 2 zips converted successfully!
# 3 zips converted successfully!
# 4 zips converted successfully!
# 5 zips converted successfully!
# 6 zips converted successfully!
# 7 zips converted successfully!
# 8 zips converted successfully!
# 9 zips converted successfully!
# 10 zips converted successfully!
# 11 zips converted successfully!
# 12 zips converted successfully!
# 13 zips converted successfully!
# 14 zips converted successfully!
# 15 zips converted successfully!
# 16 zips converted successfully!
# 17 zips converted successfully!
# 18 zips converted successfully!
# 19 zips converted successfully!
# 20 zips converted successfully!
# 21 zips converted successfully!
# 22 zips converted successfully!
# 23 zips converted successfully!
# 24 zips converted successfully!
# 25 zips converted successfully!
# 26 zips converted successfully!
# 27 zips converted successfully!
# 28 zips converted successfully!
# 29 zips converted successfully!
# ...

# %%
la_apts['Zipcode'] = zipcodes
la_apts
# Out:
#       Unnamed: 0            posted  \
# 0              0  2021-10-13 15:38
# 1              1  2021-10-13 15:38
# 2              2  2021-10-13 15:37
# 3              3  2021-10-13 15:36
# 4              4  2021-10-13 15:36
# ...          ...               ...
# 3115        3115  2021-10-13 14:42
# 3116        3116  2021-10-13 14:42
# 3117        3117  2021-10-13 14:42
# 3118        3118  2021-10-13 14:41
# 3119        3119  2021-10-13 14:40
#
#                                            neighborhood  \
# 0                                ( central LA 213/323 )
# 1                     (Los Angeles central LA 213/323 )
# 2      (616 St. Paul Ave., Los Angeles, CA central L...
# 3                      (Eagle Rock central LA 213/323 )
# 4                     (Los Angeles central LA 213/323 )
# ...                                                 ...
# 3115         (Downtown Los Angeles central LA 213/323 )
# 3116                    (Hollywood central LA 213/323 )
# ...

# %%
la_apts.to_csv('Resources/la_apts_zipcodes.csv')
